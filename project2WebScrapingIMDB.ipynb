# %% [markdown]
# Name: Thijs Anglim
# Course: Data Science Programming
# Project 2: Web Scraping

# %% [markdown]
# Importing BeautifulSoup

# %%
from bs4 import BeautifulSoup as bs

# %% [markdown]
# Checking if the urls from Box Offic Mojo permit data scraping.

# %%
import requests
url = 'https://www.boxofficemojo.com/month/june/?grossesOption=calendarGrosses'
url2 = 'https://www.boxofficemojo.com/month/july/?grossesOption=calendarGrosses'
url3 = 'https://www.boxofficemojo.com/month/august/?grossesOption=calendarGrosses'
url4 = 'https://www.boxofficemojo.com/month/september/?grossesOption=calendarGrosses'
url5 = 'https://www.boxofficemojo.com/month/october/?grossesOption=calendarGrosses'
response = requests.get(url)
status = response.status_code
if status == 200:
  page = response.text
  soup = bs(page)
else:
  print(f"Oops! Received status code {status}")
status
# Out:
# 200

# %% [markdown]
# Each of the urls return 200, which means I can use each of these links to answer questions using their data.

# %% [markdown]
# Research Questions:
# #1. For the month of June and July, how do the #1 releases compare in gross between the years 2021 to 2024?
#
# #2. Which decade in the month of August has the largest average cumulative gross for movies released within that month?
#
# #3. Which decade in the month of September has the largest average of releases?
#
# #4. In the month of October, is there any trends in the cumulative gross between 2000 and 2024?
#
# #5. For each month between June and October, how does the gross of the number #1 release compare to the #1 release in the previous two years?

# %% [markdown]
# Web Scraping Box Office Mojo's June data:

# %% [markdown]
# #1. For the month of June and July, how do the #1 releases compare in gross between the years 2021 to 2024?

# %%
response = requests.get(url)
status = response.status_code
if status == 200:
  page = response.text
  soup = bs(page)
else:
  print(f"Oops! Received status code {status}")
status
soupJune = bs(page)
print(soupJune.prettify())
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo">
#  <head>
#   <script>
#    var aPageStart = (new Date()).getTime();
#   </script>
#   <meta charset="utf-8"/>
#   <script type="text/javascript">
#    var ue_t0=ue_t0||+new Date();
#   </script>
#   <script type="text/javascript">
#    window.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;
# if (window.ue_ihb === 1) {
#
# var ue_csm = window,
#     ue_hob = +new Date();
# (function(d){var e=d.ue=d.ue||{},f=Date.now||function(){return+new Date};e.d=function(b){return f()-(b?0:d.ue_t0)};e.stub=function(b,a){if(!b[a]){var c=[];b[a]=function(){c.push([c.slice.call(arguments),e.d(),d.ue_id])};b[a].replay=function(b){for(var a;a=c.shift();)b(a[0],a[1],a[2])};b[a].isStub=1}};e.exec=function(b,a){return function(){try{return b.apply(this,arguments)}catch(c){ueLogError(c,{attribution:a||"undefined",logLevel:"WARN"})}}}})(ue_csm);
#
#
#     var ue_err_chan = 'jserr-rw';
# ...

# %%
soup.find_all('td')
# Out:
# [<td class="a-text-left mojo-header-column mojo-truncate mojo-field-type-year mojo-sort-column"><a class="a-link-normal" href="/month/june/2024/?ref_=bo_ml_table_1">2024</a></td>,
#  <td class="a-text-right mojo-field-type-money">$965,938,669</td>,
#  <td class="a-text-right mojo-number-negative mojo-number-delta mojo-field-type-percent_delta">-3.8%</td>,
#  <td class="a-text-right mojo-field-type-positive_integer">116</td>,
#  <td class="a-text-right mojo-field-type-money">$8,327,057</td>,
#  <td class="a-text-left mojo-field-type-release mojo-cell-wide"><a class="a-link-normal" href="/release/rl3638199041/?ref_=bo_ml_table_1">Inside Out 2</a></td>,
#  <td class="a-text-left mojo-field-type-genre hidden">-</td>,
#  <td class="a-text-right mojo-field-type-money hidden">-</td>,
#  <td class="a-text-right mojo-field-type-duration hidden">-</td>,
#  <td class="a-text-right mojo-field-type-money">$469,426,251</td>,
#  <td class="a-text-right mojo-field-type-percent">48.6%</td>,
# ...

# %% [markdown]
# From extracting the tables from the HTML, the years are conveniently ordered from most recent to least recent. The data for 2021 to 2024 is easily accessed.

# %%
soup.find_all(class_ = 'a-text-right mojo-field-type-money')
# Out:
# [<td class="a-text-right mojo-field-type-money">$965,938,669</td>,
#  <td class="a-text-right mojo-field-type-money">$8,327,057</td>,
#  <td class="a-text-right mojo-field-type-money">$469,426,251</td>,
#  <td class="a-text-right mojo-field-type-money">$1,003,756,784</td>,
#  <td class="a-text-right mojo-field-type-money">$10,037,567</td>,
#  <td class="a-text-right mojo-field-type-money">$331,827,099</td>,
#  <td class="a-text-right mojo-field-type-money">$968,951,150</td>,
#  <td class="a-text-right mojo-field-type-money">$9,887,256</td>,
#  <td class="a-text-right mojo-field-type-money">$362,159,641</td>,
#  <td class="a-text-right mojo-field-type-money">$401,276,723</td>,
#  <td class="a-text-right mojo-field-type-money">$4,720,902</td>,
#  <td class="a-text-right mojo-field-type-money">$88,163,505</td>,
#  <td class="a-text-right mojo-field-type-money">$3,677,627</td>,
#  <td class="a-text-right mojo-field-type-money">$167,164</td>,
# ...

# %% [markdown]
# One challenge is that these values have all the cumulative, yearly average and the #1 release gross. The first research question is looking for the values of the #1 movie grosses of 2021-2024. They are the third,sixth,ninth and twelth item on the list.

# %%
print(soup.prettify())
type(soup)
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo">
#  <head>
#   <script>
#    var aPageStart = (new Date()).getTime();
#   </script>
#   <meta charset="utf-8"/>
#   <script type="text/javascript">
#    var ue_t0=ue_t0||+new Date();
#   </script>
#   <script type="text/javascript">
#    window.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;
# if (window.ue_ihb === 1) {
#
# var ue_csm = window,
#     ue_hob = +new Date();
# (function(d){var e=d.ue=d.ue||{},f=Date.now||function(){return+new Date};e.d=function(b){return f()-(b?0:d.ue_t0)};e.stub=function(b,a){if(!b[a]){var c=[];b[a]=function(){c.push([c.slice.call(arguments),e.d(),d.ue_id])};b[a].replay=function(b){for(var a;a=c.shift();)b(a[0],a[1],a[2])};b[a].isStub=1}};e.exec=function(b,a){return function(){try{return b.apply(this,arguments)}catch(c){ueLogError(c,{attribution:a||"undefined",logLevel:"WARN"})}}}})(ue_csm);
#
#
#     var ue_err_chan = 'jserr-rw';
# ...

# %%
juneMovie_list = [ ]
stats_table = soup.find(class_='scrolling-data-table').tbody
for row in stats_table.find_all('tr'):
    gross = row.find(attrs={'data-stat':'a-text-right mojo-field-type-money','scope':'row'}).text
    year= row.find(attrs={'data-stat':'a-text-left mojo-header-column mojo-truncate mojo-field-type-year mojo-sort-column'}).text
    juneMovie_list.append({'a-text-right mojo-field-type-money':gross,'a-text-left mojo-header-column mojo-truncate mojo-field-type-year mojo-sort-column':year})
print(juneMovie_list)

juneMovies_df = pd.DataFrame(juneMovie_list)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[59], line 2
#       1 juneMovie_list = [ ]
# ----> 2 stats_table = soup.find(class_='scrolling-data-table').tbody
#       3 for row in stats_table.find_all('tr'):
#       4     gross = row.find(attrs={'data-stat':'a-text-right mojo-field-type-money','scope':'row'}).text
#
# AttributeError: 'NoneType' object has no attribute 'tbody'

# %% [markdown]
# To extract the data, I followed steps from a website called datacamp which used Regular Expression to extract the data and put it into a list. The method of using Regular Expression was considered "discouraged" because it used multiple lines of code. However, the simple version that uses a single statement did not tell me how to put the results into a list to become a dataframe. The code I use utilizes the DataFrame() function, which works only on lists.

# %% [markdown]
# The simple version of the code to remove tags looks like this:
#
# str_cells = str(row_td)
# cleantext = bs(str_cells, "lxml").get_text()
# cleantext

# %% [markdown]
# This is the code that I am using:

# %%
import re

list_rows = []
for row in rows:
    cells = row.find_all('td')
    str_cells = str(cells)
    clean = re.compile('<.*?>')
    cleantext = (re.sub(clean, '',str_cells))
    list_rows.append(cleantext)
cleantext
# Out:
# '[1975, $23,565,886, -, 1, $23,565,886, Jaws, -, -, -, $23,565,886, 100%]'

# %%
import pandas as pd
dfJune = pd.DataFrame(list_rows)
dfJune
# Out:
#                                                     0
# 0                                                  []
# 1   [2024, $965,938,669, -3.8%, 116, $8,327,057, I...
# 2   [2023, $1,003,756,784, +3.6%, 100, $10,037,567...
# 3   [2022, $968,951,150, +141.5%, 98, $9,887,256, ...
# 4   [2021, $401,276,723, +10,811.3%, 85, $4,720,90...
# 5   [2020, $3,677,627, -99.7%, 22, $167,164, Becky...
# 6   [2019, $1,149,048,054, -10.2%, 192, $5,984,625...
# 7   [2018, $1,280,071,886, +21%, 212, $6,038,074, ...
# 8   [2017, $1,058,060,041, -2.7%, 196, $5,398,265,...
# 9   [2016, $1,087,521,418, -13.4%, 200, $5,437,607...
# 10  [2015, $1,255,897,005, +19%, 172, $7,301,726, ...
# 11  [2014, $1,055,679,567, -17.7%, 200, $5,278,397...
# 12  [2013, $1,282,917,253, +18.9%, 198, $6,479,380...
# 13  [2012, $1,078,902,347, +7.2%, 192, $5,619,283,...
# 14  [2011, $1,006,668,443, -5.9%, 182, $5,531,145,...
# 15  [2010, $1,069,483,595, -4.1%, 178, $6,008,334,...
# ...

# %%
dfJune.drop(dfJune.index[5:51],inplace=True)
dfJune
# Out:
#                                                    0
# 0                                                 []
# 1  [2024, $965,938,669, -3.8%, 116, $8,327,057, I...
# 2  [2023, $1,003,756,784, +3.6%, 100, $10,037,567...
# 3  [2022, $968,951,150, +141.5%, 98, $9,887,256, ...
# 4  [2021, $401,276,723, +10,811.3%, 85, $4,720,90...

# %%
dfJune.shape
# Out:
# (5, 1)

# %% [markdown]
# The values were put into rows, but the values are seperated by commas rather than being put into their own columns.
